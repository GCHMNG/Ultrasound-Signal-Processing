# %%
from Algorithm_Functions import *

#Main Libraries 
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import datetime
import scipy.fftpack
import scipy.io as io
import sys, os, time
import math
from scipy.fft import fft, fftfreq #Fourier
import pywt # Wavelet

from skimage.restoration import denoise_wavelet #Noise
import matplotlib.patheffects as PathEffects
import seaborn as sns
from sklearn.manifold import TSNE
import time

#from tensorflow.python.framework import ops
#import tensorflow as tf
#from tensorflow import keras # And the tf and keras framework, thanks to Google

#Extra Libraries 
from mpl_toolkits import mplot3d
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import MDS
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import colors
from matplotlib import cm
from scipy.spatial.distance import pdist, squareform
import random
import pandas as pd # data processing, CSV file I/O 
import seaborn as sns #I used sns.distplot because it has more manual properties than plt.hist()
from scipy.stats import pearsonr #includes the PCC function

# %%
#o_1 = "test_191121_T1_a/Cavitation_data_500mV-NC_100-burst_1.mat"
o_2 = "test_231121_T1_a/Cavitation_data_600mV-NC_5-burst_1.mat"
o_3 = "test_231121_T2_c/Cavitation_data_600mV-NC_5-burst_1.mat"
o_4 = "test_231121_T2_d/Cavitation_data_600mV-NC_5-burst_1.mat"
trackdata = io.loadmat(o_4)
burst_data = np.array(trackdata['recorder_data'])
print(burst_data.shape)
# Out:
# (62500, 1)

# %%
burst_data_small = burst_data[10000:20000]
#------------------------------------------------------------------------------- PLOT 1: Raw Data
Plot_Time_Signal(burst_data_small)

# %%
burst_data_small = burst_data[10000:20000]
#------------------------------------------------------------------------------- PLOT 1: Raw Data
Plot_Time_Signal(burst_data_small)

# %%
spectrum = numpy.fft.fft(burst_data_small) 
plt.plot(spectrum, alpha=0.8, color='blue',label="Domain data")
# Out:
# /Users/jacobkritikos/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#------------------------------------------------------------------------------- PLOT: FFT
Plot_FFT_Signal(burst_data_small,False)
